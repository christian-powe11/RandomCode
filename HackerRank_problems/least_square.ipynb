# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(42)

# Generate random points
num_points = 50
x = np.random.uniform(0, 10, num_points)
y = np.random.uniform(0, 50, num_points)

# Add some noise to the points
noise = np.random.normal(0, 5, num_points)
y = 5*x + noise

# Perform linear regression
mean_x = np.mean(x)
mean_y = np.mean(y)

numerator, denominator = 0,0
for i in range(num_points):
    numerator += (x[i] - mean_x) * (y[i] - mean_y)
    denominator += (x[i] - mean_x)**2
m = numerator/denominator
c = mean_y - (m * mean_x)
print(m,c)
line_bestfit = c+ m *x



# Plot the points and regression line
plt.scatter(x, y, color='blue', label='Data Points')
plt.plot(x, line_bestfit, color='red', label='Linear Regression')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.legend()
plt.grid(True)
plt.savefig('regression.png')
plt.show()
# Out:
# 4.32975078883323 3.084707207935786
